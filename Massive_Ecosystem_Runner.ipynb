# %% [markdown]
# # 🌍 PockePocke Massive Ecosystem Simulator
# このノートブックでは、**10万人のプレイヤー**（ガチ勢・ロマン派・コピー層）が入り乱れるポケポケのメタゲーム環境をシミュレートします。
#
# ### シミュレーションの構成
# - **ガチ勢 (60%)**: 最強デッキ100種類をマイナーチェンジしながら使用
# - **ロマン派 (30%)**: 面白いカードや独自のコンボを追求
# - **コピー層 (10%)**: ロマン派のデッキをそのまま使用
#
# どのカードが最も勝利に貢献し、どのアーキタイプが生き残るかを分析します。

# %%
# 1. リポジトリの取得と環境構築
# !git clone https://github.com/B221393/Pockepocke.git
# %cd Pockepocke
# !pip install numpy pandas matplotlib beautifulsoup4
# !mkdir -p logs results

# %% [markdown]
# ## 🚀 シミュレーションの実行
# 10万試合のランクマッチをエミュレートします（数分かかります）。

# %%
# 2. エコシステム・シミュレーターの実行
# 引数で試合数を指定可能（デフォルト10,000、Colabなら100,000も余裕です）
# !python ecosystem_sim.py

# %% [markdown]
# ## 📊 結果の分析とレポート表示
# シミュレーション結果から、最強のアーキタイプとMVPカードを表示します。

# %%
from IPython.display import Markdown, display
import os

report_path = 'logs/ecosystem_report.md'
if os.path.exists(report_path):
    display(Markdown(report_path))
else:
    print("レポートが見つかりません。シミュレーションを実行してください。")

# %% [markdown]
# ## 💾 結果の保存
# 詳細なデータを手元に保存したい場合は、以下のセルを実行してください。

# %%
# from google.colab import files
# if os.path.exists('logs/ecosystem_report.md'):
#     files.download('logs/ecosystem_report.md')
