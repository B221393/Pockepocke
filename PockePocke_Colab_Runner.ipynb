# %% [markdown]
# # PockePocke Meta Simulator (Colab / VSCode Remote Runner)
# リモートカーネル（Colab等）の初期状態では、PythonスクリプトやカードデータのCSVファイルが存在していません。そのため、ローカルのファイル群をクラウド上に持っていく必要があります。
#
# **【実行前の準備】**
# VSCodeのファイルエクスプローラーから、デスクトップにある **`pockepocke_colab.zip`** を、このノートブックの横（リモートのルートディレクトリ `/content/` ）にドラッグ＆ドロップでアップロードしてください。

# %%
# 1. アップロードしたZIPファイルをリモートサーバー上に解凍します
# !unzip -o pockepocke_colab.zip

import os
os.makedirs('gui', exist_ok=True)
os.makedirs('logs/autonomous', exist_ok=True)

# 2. 100万人規模（10,000デッキ）のシミュレーターエンジンを超高速起動します
# !python autonomous_loop.py
# Out:
# unzip:  cannot find or open pockepocke_colab.zip, pockepocke_colab.zip.zip or pockepocke_colab.zip.ZIP.
# python3: can't open file '/content/autonomous_loop.py': [Errno 2] No such file or directory
